# %% [markdown]
# ## Install and import the necessary libraries

# %%
# %%capture

# !pip install -r  requirements.txt

# %%
import torch
from langchain.llms import OpenAI
from langchain.chains import ConversationalRetrievalChain
from langchain.chains.question_answering import load_qa_chain
from langchain.document_loaders import DirectoryLoader
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.llms import HuggingFacePipeline
from langchain.memory import ConversationBufferMemory
from langchain.prompts import PromptTemplate
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from transformers import AutoTokenizer, GenerationConfig, TextStreamer, pipeline
import pandas as pd
from langchain_experimental.open_clip import OpenCLIPEmbeddings
from typing import List, Tuple
from langchain_core.pydantic_v1 import BaseModel

from langchain.output_parsers import PydanticOutputParser
import os

# %% [markdown]
# ## Initialize model

# %%
MODEL_NAME = 'gpt-3.5-turbo-instruct'
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
model = OpenAI(model_name=MODEL_NAME, openai_api_key="OPENAI_API_KEY", temperature=0)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(

# %%
generation_prompt = """
Generate exactly 15 real estate listings as a list of listings from Cox's Bazar neighborhood. All the prices should be in taka, and the location should be in Cox's Bazar, Bangladesh. Here are sample listings enclosed in ticks. Please follow the format and make sure no fields are missing.
Create them in this format:
Neighborhood: Inani Beach, Cox's Bazar
Price (Taka): 
3,500,0
Bedrooms: 3
Bathrooms: 2.5
House Size (sqft): 2,000
Description: Unwind and recharge in this modern 2-bedroom condo, perfectly situated just steps from the pristine shores of Inani Beach. Wake up to the calming sound of waves and enjoy breathtaking ocean views from your private balcony. The light-filled interior features an open floor plan, ideal for entertaining. The sleek kitchen boasts stainless steel appliances and granite countertops, perfect for whipping up gourmet meals. Unwind after a long day on the beach in the spacious living area or take a refreshing dip in the sparkling community pool.
Neighborhood Description: Sea Breeze Lane is a tranquil beachside community offering the perfect blend of relaxation and convenience. Spend your days soaking up the sun on the white sand beaches or explore the vibrant marine life by snorkeling or diving. After a day at the beach, grab a bite at one of the many beachfront cafes or restaurants. Enjoy easy access to local shops, grocery stores, and nightlife options, all within walking distance.
Make sure you generate exactly 15 rows. Ensure the property description aligns with the location and makes it attractive.

Format the with clear titles for each part. Use the same style as the example to list exactly 15 different properties. Make sure you don't generate any less than 15 listings.
"""
# Out:
# /home/student/.local/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(

# %%
class RealEstate(BaseModel):
    neighborhood: str
    price: str
    bedrooms: str
    bathrooms: str
    house_size: str
    description: str
    neighborhood_description: str

class ListingCollection(BaseModel):
    listings: List[RealEstate]


parser = PydanticOutputParser(pydantic_object=ListingCollection)

prompt = PromptTemplate(
    template="{instruction}\n{format_instructions}\n",
    input_variables=["instruction"],
    partial_variables={"format_instructions": parser.get_format_instructions},
)

# %%
chain = prompt | model | parser
result = chain.invoke({"instruction": generation_prompt})

# %%
from fastapi.encoders import jsonable_encoder
import pandas as pd 

listings = jsonable_encoder(result.listings)

df = pd.DataFrame(listings)

df.to_csv("cox_real_estate_listings.csv", index=True)
print("Created cox_real_estate_listings.csv file")
# Out:
# Created cox_real_estate_listings.csv file

# %%
df = pd.read_csv('cox_real_estate_listings.csv')
df.head()
# Out:
#    Unnamed: 0                                Neighborhood  Price  Bedrooms  \
# 0           0          Sea Breeze Lane (near Inani Beach)  45000         2
# 1           1  Himachori Coral Reef (near Himchori Beach)  50000         1
# 2           2    Parki Beach Community (near Parki Beach)  38000         2
# 3           3   Kolatoli Beachfront (near Kolatoli Beach)  60000         3
# 4           4  Kongkong Beach Vista (near Kongkong Beach)  42000         1
#
#    Bathrooms  House Size                                        Description  \
# 0        1.5      1000.0  Unwind and recharge in this modern 2-bedroom c...
# 1        1.0       700.0  Embrace a minimalist lifestyle in this chic st...
# 2        1.0       850.0  Immerse yourself in the vibrant energy of Park...
# 3        2.0      1500.0  Indulge in luxurious beachfront living in this...
# 4        1.0       550.0  Unwind in this cozy studio apartment with a pr...
#
#                             Neighborhood Description
# 0  Sea Breeze Lane offers a tranquil escape just ...
# 1  Himachori Coral Reef offers a unique opportuni...
# 2  Parki Beach Community offers a vibrant atmosph...
# 3  Kolatoli Beachfront offers the epitome of luxu...
# 4  Kongkong Beach Vista offers a tranquil escape ...

# %%
df.rename(columns={'Unnamed: 0': 'id'}, inplace=True)

# %%
df.head()
# Out:
#    id                                Neighborhood  Price  Bedrooms  Bathrooms  \
# 0   0          Sea Breeze Lane (near Inani Beach)  45000         2        1.5
# 1   1  Himachori Coral Reef (near Himchori Beach)  50000         1        1.0
# 2   2    Parki Beach Community (near Parki Beach)  38000         2        1.0
# 3   3   Kolatoli Beachfront (near Kolatoli Beach)  60000         3        2.0
# 4   4  Kongkong Beach Vista (near Kongkong Beach)  42000         1        1.0
#
#    House Size                                        Description  \
# 0      1000.0  Unwind and recharge in this modern 2-bedroom c...
# 1       700.0  Embrace a minimalist lifestyle in this chic st...
# 2       850.0  Immerse yourself in the vibrant energy of Park...
# 3      1500.0  Indulge in luxurious beachfront living in this...
# 4       550.0  Unwind in this cozy studio apartment with a pr...
#
#                             Neighborhood Description
# 0  Sea Breeze Lane offers a tranquil escape just ...
# 1  Himachori Coral Reef offers a unique opportuni...
# 2  Parki Beach Community offers a vibrant atmosph...
# 3  Kolatoli Beachfront offers the epitome of luxu...
# 4  Kongkong Beach Vista offers a tranquil escape ...

# %% [markdown]
# # Prepare our listings for Chromadb
# We convert our synthetically generated listings to insert in Chromadb for performing vector search

# %%
property_texts = []

property_ids = [{'id': i} for i in range(len(df))]

property_template = """
Description: {}
Neighborhood Description: {}
Price: {}
Bedrooms: {}
Bathrooms: {}
House Size (sqft): {}
"""

for index, row in df.iterrows():
    property_texts.append(property_template.format(
        row['Description'],
        row['Neighborhood Description'],
        row['Price'],
        row['Bedrooms'],
        row['Bathrooms'],
        row['House Size']
    ))

# %%
property_texts
# Out:
# ["\nDescription: Unwind and recharge in this modern 2-bedroom condo, a stone's throw from the pristine shores of Inani Beach. Listen to the calming sound of waves from your private balcony and enjoy breathtaking ocean views. The light-filled interior features an open floor plan, perfect for entertaining. Prepare gourmet meals in the sleek kitchen with stainless steel appliances and granite countertops. Dive into the sparkling community pool after a long day at the beach. Embrace the relaxed beach lifestyle in Sea Breeze Lane.\nNeighborhood Description: Sea Breeze Lane offers a tranquil escape just steps away from the vibrant Inani Beach. Explore the diverse marine life by snorkeling or diving, or simply soak up the sun on the white sand beaches. Enjoy a variety of restaurants and cafes within walking distance, or head to the local shops for your essentials. This community is perfect for young professionals seeking a peaceful haven close to the beach.\nPrice: 45000\nBedrooms: 2\nBathrooms: 1.5\nHouse Size (sqft): 1000.0\n",
#  '\nDescription: Embrace a minimalist lifestyle in this chic studio apartment, boasting stunning views of the coral reefs just off Himchori Beach. This cleverly designed space maximizes functionality, featuring a well-equipped kitchen, a comfortable sleeping area with ample natural light, and a stylish bathroom. Step out onto your private balcony and witness the vibrant marine life below. Take a refreshing dip in the crystal-clear waters of Himchori Beach, just a short walk away. Enjoy the relaxed atmosphere and stunning scenery of this unique beachfront community.\nNeighborhood Description: Himachori Coral Reef offers a unique opportunity to live amongst the wonders of the underwater world. Explore the vibrant coral reefs teeming with colorful fish, just steps from your doorstep. Kayak or paddleboard along the calm coastline, or simply relax on the pristine beach. This close-knit community fosters a peaceful environment, perfect for young professionals seeking a serene beach escape.\nPrice: 50000\nBedrooms: 1\nBathrooms: 1.0\nHouse Size (sqft): 700.0\n',
#  '\nDescription: Immerse yourself in the vibrant energy of Parki Beach Community. This charming 2-bedroom apartment boasts a spacious balcony overlooking the bustling beach scene. Enjoy the convenience of having shops, restaurants, and cafes right at your doorstep. The light-filled interior features modern finishes and an open layout, perfect for entertaining friends. After a day of exploring the beach, unwind in the comfortable living area or take a refreshing dip in the on-site pool. Embrace the dynamic beach lifestyle in the heart of Parki Beach Community.\nNeighborhood Description: Parki Beach Community offers a vibrant atmosphere perfect for young professionals seeking a social beach lifestyle. Enjoy a variety of water sports activities like surfing and kayaking, or simply relax on the lively beach. Mingle with fellow residents at the community clubhouse or explore the diverse selection of restaurants and cafes. This dynamic community provides endless entertainment and convenience, all within walking distance.\nPrice: 38000\nBedrooms: 2\nBathrooms: 1.0\nHouse Size (sqft): 850.0\n',
#  "\nDescription: Indulge in luxurious beachfront living in this spacious 3-bedroom home located directly on Kolatoli Beach. Wake up to the sound of waves and enjoy breathtaking ocean views from your private balcony. The light-filled interior features high-end finishes and a modern open floor plan. Relax in the spacious living area or prepare gourmet meals in the chef's kitchen. Unwind after a day at the beach in your luxurious master suite with a jacuzzi bathtub. Embrace the ultimate beachfront lifestyle in this stunning Kolatoli Beachfront property.\nNeighborhood Description: Kolatoli Beachfront offers the epitome of luxurious beachfront living. Enjoy direct access to the bustling Kolatoli Beach, a haven for water sports activities and lively entertainment. Explore the diverse shops and restaurants lining the beachfront, or simply relax on the pristine sand.\nPrice: 60000\nBedrooms: 3\nBathrooms: 2.0\nHouse Size (sqft): 1500.0\n",
#  '\nDescription: Unwind in this cozy studio apartment with a private balcony overlooking the breathtaking vista of Kongkong Beach. The cleverly designed space maximizes comfort, featuring a well-equipped kitchenette, a comfortable sleeping area bathed in natural light, and a modern bathroom. Take a short stroll down to the beach and enjoy the serenity of Kongkong Beach, known for its calmer waters and diverse seashells. Explore the nearby hiking trails or rent bicycles to discover the surrounding coastal beauty. This peaceful community offers a perfect escape for young professionals seeking a relaxed beach lifestyle.\nNeighborhood Description: Kongkong Beach Vista offers a tranquil escape from the hustle and bustle, ideal for those seeking a serene beach experience. The calm waters of Kongkong Beach are perfect for swimming, kayaking, or simply relaxing on the shore. Explore the diverse seashells along the coastline or venture out on nearby hiking trails for breathtaking coastal views. This peaceful community fosters a close-knit atmosphere, perfect for young professionals seeking a relaxing haven near the beach.\nPrice: 42000\nBedrooms: 1\nBathrooms: 1.0\nHouse Size (sqft): 550.0\n',
#  "\nDescription: Soar above the ordinary in this modern 2-bedroom townhouse, situated just steps from the vibrant Inani Beach. This spacious home boasts a private rooftop terrace with stunning panoramic ocean views, perfect for entertaining or simply soaking up the sunshine. The light-filled interior features modern finishes and an open floor plan. Prepare gourmet meals in the sleek kitchen and unwind in the comfortable living area. Enjoy the convenience of having shops, restaurants, and cafes within walking distance. Embrace the elevated beach lifestyle in your Seagull's Nest haven.\nNeighborhood Description: Seagull's Nest offers a unique opportunity to experience the best of both worlds - stunning beach views and convenient access to the vibrant Inani Beach scene. Enjoy a variety of water sports activities, explore the diverse shops and restaurants, or simply relax on the white sand beaches. This community caters to young professionals seeking an elevated beach lifestyle with breathtaking views and easy access to all the action.\nPrice: 52000\nBedrooms: 2\nBathrooms: 1.5\nHouse Size (sqft): 1200.0\n",
#  '\nDescription: Find your serenity in this charming studio apartment nestled in the peaceful Serenity Bay community near Patenga Beach. This light-filled space features a well-equipped kitchenette, a comfortable sleeping area, and a modern bathroom. Step out onto your private balcony and enjoy the calming sounds of nature. Take a short walk to Patenga Beach and witness the breathtaking sunsets over the Bay of Bengal. Explore the nearby fishing villages or simply relax on the pristine beach. This budget-friendly community offers a tranquil escape for young professionals seeking a peaceful beach retreat.\nNeighborhood Description: Serenity Bay offers a tranquil escape from the crowds, perfect for those seeking a peaceful and budget-friendly beach experience. Patenga Beach, known for its breathtaking sunsets, is just a short walk away. Explore the nearby fishing villages and immerse yourself in the local culture, or simply relax on the pristine beach and listen to the calming sounds of the waves. This close-knit community fosters a relaxed atmosphere, perfect for young professionals seeking an affordable and serene haven near the beach.\nPrice: 35000\nBedrooms: 1\nBathrooms: 1.0\nHouse Size (sqft): 600.0\n',
#  '\nDescription: Escape to your own private haven in this charming 2-bedroom cottage nestled near South Beach. This light-filled home boasts a cozy living area with a fireplace, perfect for relaxing after a day exploring the beach. The well-equipped kitchen is ideal for whipping up delicious meals to enjoy on your private patio overlooking the lush tropical gardens. Enjoy the serenity of South Beach, known for its secluded coves and calm waters. Explore the nearby nature trails or rent paddleboards to discover hidden coves. This peaceful community offers a perfect retreat for young professionals seeking a secluded beach lifestyle.\nNeighborhood Description: South Beach Hideaway offers a tranquil escape from the crowds, ideal for those seeking a secluded beach experience. South Beach, known for its calm waters and hidden coves, is perfect for swimming, snorkeling, or simply relaxing on the shore. Explore the nearby nature trails and immerse yourself in the beauty of the surrounding tropical landscape, or rent paddleboards to discover hidden coves. This peaceful community fosters a close-knit atmosphere, perfect for young professionals seeking a secluded haven near the beach.\nPrice: 48000\nBedrooms: 2\nBathrooms: 1.0\nHouse Size (sqft): 900.0\n',
#  '\nDescription: Embrace the panoramic views in this modern studio apartment located in the Dune View Apartments near Chanderia Beach. The light-filled space features floor-to-ceiling windows showcasing breathtaking vistas of the rolling sand dunes and the sparkling ocean beyond. The well-equipped kitchenette allows you to prepare quick meals, while the spacious balcony provides the perfect spot for enjoying the sunset. Take a short walk down to Chanderia Beach, known for its pristine sands and calm waters. Explore the nearby shops and restaurants or simply relax and soak up the sun. This affordable community offers a perfect retreat for young professionals seeking a convenient beach lifestyle with stunning views.\nNeighborhood Description: Dune View Apartments offer a unique opportunity to experience breathtaking panoramic views and convenient access to the vibrant Chanderia Beach scene. Enjoy a variety of water sports activities, explore the diverse shops and restaurants, or simply relax on the pristine sands. This community caters to young professionals seeking an affordable beach lifestyle with stunning views and easy access to all the action.\nPrice: 40000\nBedrooms: 1\nBathrooms: 1.0\nHouse Size (sqft): 750.0\n',
#  "\nDescription: Indulge in spacious living in this modern 3-bedroom townhouse located in the tranquil Shores community near Agamed Khon. This light-filled home boasts an open floor plan and modern finishes, perfect for entertaining friends and family. Relax in the spacious living area or prepare gourmet meals in the chef's kitchen. Enjoy the convenience of having a private balcony overlooking the lush greenery and a short walk to the serene Agamed Khon beach. Explore the nearby historical sites or simply relax on the beach and listen to the calming sounds of the waves. This upscale community offers a perfect retreat for young professionals seeking a peaceful and spacious haven near the beach.\nNeighborhood Description: Tranquil Shores offers a serene escape from the crowds, perfect for those seeking a peaceful and upscale beach experience. Agamed Khon beach, known for its pristine waters and historical significance, is just a short walk away. Explore the nearby historical sites and immerse yourself in the rich cultural heritage, or simply relax on the beach and listen to the calming sounds of the waves. This upscale community fosters a close-knit atmosphere, perfect for young professionals seeking a spacious and peaceful haven near the beach.\nPrice: 58000\nBedrooms: 3\nBathrooms: 2.0\nHouse Size (sqft): 1300.0\n",
#  '\nDescription: Become an eco-conscious resident in this charming 2-bedroom bungalow nestled in the Turtle Bay Sanctuary near Seahorse Point. This light-filled home features sustainable materials and energy-efficient appliances, perfect for those seeking an eco-friendly lifestyle. Relax on your private porch overlooking a protected turtle nesting area. Take a short walk down to Seahorse Point, a haven for snorkeling enthusiasts with its vibrant coral reefs. Explore the nearby conservation efforts or participate in beach cleanups. This eco-friendly community offers a perfect retreat for young professionals seeking a sustainable and responsible beach lifestyle.\nNeighborhood Description: Turtle Bay Sanctuary offers a unique opportunity to live amongst nature and contribute to a sustainable future. Seahorse Point, known for its vibrant coral reefs teeming with marine life, is a haven for snorkelers and divers. Participate in various conservation efforts organized by the community or simply relax on the beach and witness the beauty of the protected turtle nesting area. This close-knit community fosters a responsible and eco-conscious atmosphere, perfect for young professionals seeking a meaningful and sustainable haven near the beach.\nPrice: 43000\nBedrooms: 2\nBathrooms: 1.5\nHouse Size (sqft): 800.0\n',
#  '\nDescription: Immerse yourself in the heart of the action in this luxurious 2-bedroom villa located in the Coastal Breeze Villas near Kolatoli Beach. This light-filled home boasts modern finishes, a private balcony overlooking the bustling beach scene, and access to a sparkling community pool. The spacious living area and gourmet kitchen are perfect for entertaining friends after a day of exploring the vibrant Kolatoli Beach. Enjoy the convenience of having shops, restaurants, and nightlife options all within walking distance. Embrace the dynamic beach lifestyle in your Coastal Breeze haven.\nNeighborhood Description: Coastal Breeze Villas offer a vibrant and convenient location in the heart of the action, perfect for young professionals seeking a dynamic beach lifestyle. Kolatoli Beach, known for its bustling scene and diverse activities, is just steps away. Explore the variety of shops and restaurants, enjoy water sports activities, or simply relax on the lively beach. This community caters to young professionals seeking an exciting and convenient beach lifestyle with endless entertainment options close at hand.\nPrice: 62000\nBedrooms: 2\nBathrooms: 2.0\nHouse Size (sqft): 1100.0\n',
#  '\nDescription: Find your peace in this cozy studio apartment nestled in the Hidden Cove Retreat near Inani Beach. This cleverly designed space maximizes comfort, featuring a well-equipped kitchenette, a comfortable sleeping area with ample natural light, and a modern bathroom. Step out onto your private balcony and enjoy the tranquility of a hidden cove accessible only by a short walk through lush greenery. Take a refreshing dip in the crystal-clear waters of a secluded beach and explore the diverse marine life with minimal crowds. This budget-friendly community offers a perfect escape for young professionals seeking a peaceful and secluded haven near the beach.\nNeighborhood Description: Hidden Cove Retreat offers a tranquil escape from the crowds, ideal for those seeking a secluded and budget-friendly beach experience. A secluded cove, accessible only by a short walk through lush greenery, offers pristine waters and a chance to experience the beauty of the beach away from the hustle and bustle. Explore the diverse marine life with minimal crowds or simply relax on the beach and listen to the calming sounds of the waves. This close-knit community fosters a relaxed atmosphere, perfect for young professionals seeking an affordable and secluded haven near the beach.\nPrice: 37000\nBedrooms: 1\nBathrooms: 1.0\nHouse Size (sqft): 650.0\n',
#  '\nDescription: Embrace a unique eco-adventure in this rustic 2-bedroom lodge nestled within the Mangrove Point Eco-Lodge near Teknaf Peninsula. This elevated cabin features wooden interiors and large windows, offering breathtaking views of the surrounding mangrove forest. Enjoy eco-friendly amenities like solar power and rainwater harvesting. Explore the diverse ecosystems of the Teknaf Peninsula through guided kayak tours or nature walks. This unique community offers a perfect retreat for young professionals seeking a sustainable and adventurous beach experience.\nNeighborhood Description: Mangrove Point Eco-Lodge offers a unique opportunity to immerse yourself in a pristine natural environment near the Teknaf Peninsula. Explore the diverse ecosystems of the mangrove forest and surrounding waterways through guided tours or independent exploration. Kayak through the calm waters, spotting an abundance of birdlife, or participate in beach clean-up initiatives. This close-knit community fosters a sustainable and adventurous atmosphere, perfect for young professionals seeking an unforgettable beach escape.\nPrice: 55000\nBedrooms: 2\nBathrooms: 1.5\nHouse Size (sqft): 900.0\n',
#  '\nDescription: Unwind and reconnect with nature in this charming studio apartment located in the Sea Star Shores near Himchori Beach. This light-filled space features a balcony overlooking lush tropical gardens, leading to a short pathway to the pristine shores of Himchori Beach. The well-equipped kitchenette allows you to prepare quick meals, while the spacious balcony provides the perfect spot for stargazing under the clear night sky. Enjoy the serenity of Himchori Beach, known for its calm waters and diverse seashells. Explore the nearby hiking trails or participate in yoga sessions on the beach. This peaceful community offers a perfect retreat for young professionals seeking a nature-oriented beach lifestyle.\nNeighborhood Description: Sea Star Shores offers a tranquil escape from the crowds, ideal for those seeking a nature-oriented and relaxing beach experience. Himchori Beach, known for its calm waters and diverse seashells, is just a short walk away. Explore the nearby hiking trails and immerse yourself in the beauty of the surrounding tropical landscape, or participate in yoga sessions on the beach and connect with nature. This peaceful community fosters a close-knit atmosphere, perfect for young professionals seeking a relaxing and nature-oriented haven near the beach.\nPrice: 47000\nBedrooms: 1\nBathrooms: 1.0\nHouse Size (sqft): 700.0\n',
#  "\nDescription: Immerse yourself in the local culture in this cozy studio apartment located in the Fisherman's Wharf Apartments near Chanderia Beach. This light-filled space features a balcony overlooking the bustling harbor, offering a glimpse into the daily lives of local fishermen. The well-equipped kitchenette allows you to prepare fresh seafood purchased from the nearby market. Take a short walk down to Chanderia Beach, known for its pristine sands and calm waters. Explore the vibrant fish market or join a boat tour for a unique perspective of the coastline. This affordable community offers a perfect retreat for young professionals seeking an authentic and cultural beach experience.\nNeighborhood Description: Fisherman's Wharf Apartments offer a unique opportunity to experience the vibrant local culture near Chanderia Beach. The bustling harbor right outside your window offers a glimpse into the daily lives of local fishermen. Explore the vibrant fish market and discover the freshest seafood catch, or join a boat tour for a unique perspective of the coastline. Chanderia Beach, known for its pristine sands and calm waters, is just a short walk away. This close-knit community fosters a welcoming atmosphere, perfect for young professionals seeking an authentic and cultural haven near the beach.\nPrice: 39000\nBedrooms: 1\nBathrooms: 1.0\nHouse Size (sqft): nan\n"]

# %% [markdown]
# ## Create a collection

# %%
db = Chroma(
    collection_name="cox_listings", embedding_function=OpenCLIPEmbeddings()
)
# Out:
# open_clip_pytorch_model.bin:   0%|          | 0.00/3.94G [00:00<?, ?B/s]

# %% [markdown]
# # Insert the listings

# %%
db.add_texts(texts=property_texts, metadatas = property_ids)
# Out:
# ['65ec7236-24f9-11ef-a6d8-16ffd57d1cf7',
#  '65ec72f4-24f9-11ef-a6d8-16ffd57d1cf7',
#  '65ec7326-24f9-11ef-a6d8-16ffd57d1cf7',
#  '65ec734e-24f9-11ef-a6d8-16ffd57d1cf7',
#  '65ec736c-24f9-11ef-a6d8-16ffd57d1cf7',
#  '65ec738a-24f9-11ef-a6d8-16ffd57d1cf7',
#  '65ec73b2-24f9-11ef-a6d8-16ffd57d1cf7',
#  '65ec73d0-24f9-11ef-a6d8-16ffd57d1cf7',
#  '65ec73ee-24f9-11ef-a6d8-16ffd57d1cf7',
#  '65ec740c-24f9-11ef-a6d8-16ffd57d1cf7',
#  '65ec742a-24f9-11ef-a6d8-16ffd57d1cf7',
#  '65ec7448-24f9-11ef-a6d8-16ffd57d1cf7',
#  '65ec7470-24f9-11ef-a6d8-16ffd57d1cf7',
#  '65ec7498-24f9-11ef-a6d8-16ffd57d1cf7',
#  '65ec74b6-24f9-11ef-a6d8-16ffd57d1cf7',
#  '65ec74d4-24f9-11ef-a6d8-16ffd57d1cf7']

# %% [markdown]
# # Perform semantic search and personalize the responses

# %%
def get_matched_listings(user_preferences: List[str], top_k: int = 5) -> List[int]:

    combined_preferences = '\n'.join(user_preferences)
    results = db.similarity_search(combined_preferences, k=top_k * 2)

    return [result.metadata['id'] for result in results if result.metadata['id'] not in results[:top_k]]

# %% [markdown]
# ## Add a new prompt template for custom listing generation
# We will use in-context learning to customize the listings based on user preferences. To do so, we will create a new prompt template
# that will take an `instruction` and `buyer preferences` as context. Then will use the `buyer preferences` to retrieve relevant
# listings and augment the `instruction`, `preference` and relevant `listings` to query an llms to create a new personalized listing.

# %% [markdown]
# ## Create instruction

# %%
instructions = 'Create a short description tailored to each listing, capturing the kind of what the buyer desires and emphasizing those key features to attract their interest.'

# %% [markdown]
# ## Create prompt template with validation

# %%
class ListingSummary(BaseModel):
    listing_id: int
    summary_text: str

class SummaryCollection(BaseModel):
    listing_summaries: List[ListingSummary]


parser = PydanticOutputParser(pydantic_object=SummaryCollection)
prompt_template = PromptTemplate(
    template="{instruction}\nBuyer Preferences:\n{buyer_preferences}\nListings:\n{listings}\n\n{format_instructions}",
    input_variables=["instruction", "buyer_preferences", "listings"],
    partial_variables={"format_instructions": parser.get_format_instructions},
)

# %% [markdown]
# ## Create function to retrieve relvant listings and augment them with preferences and instruction to get customized listings

# %%
cached_summaries = {}

def generate_customized_summaries(buyer_preferences: List[str], top_k: int = 5) -> List[Tuple[int, str]]:

    top_listings = get_matched_listings(buyer_preferences, top_k)

    listings = [('ID:' + str(listing_id), property_texts[listing_id]) for listing_id in top_listings]

    query = prompt_template.format(
        instruction=instructions,
        buyer_preferences='\n'.join(buyer_preferences),
        listings='\n'.join([''.join(listing) for listing in listings])
    )

    response = []
    for summary in parser.parse(model(query)).listing_summaries:
        response.append((summary.listing_id, summary.summary_text))
        cached_summaries[summary.listing_id] = summary.summary_text

    return response

# %% [markdown]
# ## Test out our personalized listings generator

# %%
questions = ["What type of neighborhood are you aiming for?",
             "Which house size best suits your needs?",
             "How many bed do you want?",
             "How many bath do you want?",
             "What is the price range you want?"]

preferences = [
        "I'm targeting peaceful communities near popular beaches in Cox's Bazar, offering a relaxed and scenic atmosphere."
        "The available house sizes should range from 500 to 1500 square feet, a medium sized place is best for me.",
        "I am looking for ideally a three bedroom space",
        "The house needs to have two bathrooms, one for personal and one for guests",
        "My budget is around 30000 thousand for rent, so rent should be within 20000 to 30000 "
]

# %%
result = generate_customized_summaries(preferences)
print(result)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# [(8, 'Embrace the panoramic views in this modern studio apartment located in the Dune View Apartments near Chanderia Beach. The light-filled space features floor-to-ceiling windows showcasing breathtaking vistas of the rolling sand dunes and the sparkling ocean beyond. The well-equipped kitchenette allows you to prepare quick meals, while the spacious balcony provides the perfect spot for enjoying the sunset. Take a short walk down to Chanderia Beach, known for its pristine sands and calm waters. Explore the nearby shops and restaurants or simply relax and soak up the sun. This affordable community offers a perfect retreat for young professionals seeking a convenient beach lifestyle with stunning views.'), (15, "Immerse yourself in the local culture in this cozy studio apartment located in the Fisherman's Wharf Apartments near Chanderia Beach. This light-filled space features a balcony overlooking the bustling harbor, offering a glimpse into the daily lives of local fishermen. The well-equipped kitchenette allows you to prepare fresh seafood purchased from the nearby market. Take a short walk down to Chanderia Beach, known for its pristine sands and calm")]

# %%
preferences2 = [
  "I'm seeking an eco-friendly community close to the beach, with access to sustainability initiatives and a focus on responsible living.",
  "A studio or one-bedroom apartment (around 600-800 square feet) would be ideal for my minimalist lifestyle.",
  "While I can manage with one bathroom, having 1.5 bathrooms would provide extra convenience, especially for guests.",
  "Budget is a key factor, with my ideal range being between 35,000 taka and 45,000 taka per month.",
  "Proximity to shops, restaurants, and cafes is important for me, as I enjoy a vibrant and convenient beach lifestyle."
]
result = generate_customized_summaries(preferences2)
print(result)
# Out:
# [(12, 'Find your peace in this cozy studio apartment nestled in the Hidden Cove Retreat near Inani Beach. This cleverly designed space maximizes comfort, featuring a well-equipped kitchenette, a comfortable sleeping area with ample natural light, and a modern bathroom. Step out onto your private balcony and enjoy the tranquility of a hidden cove accessible only by a short walk through lush greenery. Take a refreshing dip in the crystal-clear waters of a secluded beach and explore the diverse marine life with minimal crowds. This budget-friendly community offers a perfect escape for young professionals seeking a peaceful and secluded haven near the beach.'), (1, 'Embrace a minimalist lifestyle in this chic studio apartment, boasting stunning views of the coral reefs just off Himchori Beach. This cleverly designed space maximizes functionality, featuring a well-equipped kitchen, a comfortable sleeping area with ample natural light, and a stylish bathroom. Step out onto your private balcony and witness the vibrant marine life below. Take a refreshing dip in the crystal-clear waters of Himchori Beach, just a short walk away. Enjoy the relaxed atmosphere')]
